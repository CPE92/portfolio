# %%
# !ls /kaggle/input/pyvips-python-and-deb-package
 # intall the deb packages
# !dpkg -i --force-depends /kaggle/input/pyvips-python-and-deb-package/linux_packages/archives/*.deb
 # install the python wrapper
# !pip install pyvips -f /kaggle/input/pyvips-python-and-deb-package/python_packages/ --no-index
# Out:
# linux_packages	python_packages
# Selecting previously unselected package autoconf.
# (Reading database ... 107763 files and directories currently installed.)
# Preparing to unpack .../autoconf_2.69-11.1_all.deb ...
# Unpacking autoconf (2.69-11.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../automake_1%3a1.16.1-4ubuntu6_all.deb ...
# Unpacking automake (1:1.16.1-4ubuntu6) ...
# Selecting previously unselected package autopoint.
# Preparing to unpack .../autopoint_0.19.8.1-10build1_all.deb ...
# Unpacking autopoint (0.19.8.1-10build1) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package bzip2-doc.
# Preparing to unpack .../bzip2-doc_1.0.8-2_all.deb ...
# Unpacking bzip2-doc (1.0.8-2) ...
# Selecting previously unselected package debhelper.
# Preparing to unpack .../debhelper_12.10ubuntu1_all.deb ...
# Unpacking debhelper (12.10ubuntu1) ...
# Selecting previously unselected package dh-autoreconf.
# Preparing to unpack .../dh-autoreconf_19_all.deb ...
# Unpacking dh-autoreconf (19) ...
# Selecting previously unselected package dh-strip-nondeterminism.
# Preparing to unpack .../dh-strip-nondeterminism_1.7.0-1_all.deb ...
# Unpacking dh-strip-nondeterminism (1.7.0-1) ...
# Selecting previously unselected package dwz.
# Preparing to unpack .../archives/dwz_0.13-5_amd64.deb ...
# Unpacking dwz (0.13-5) ...
# Selecting previously unselected package file.
# Preparing to unpack .../file_1%3a5.38-4_amd64.deb ...
# Unpacking file (1:5.38-4) ...
# Selecting previously unselected package firefox.
# Preparing to unpack .../firefox_118.0.2+build2-0ubuntu0.20.04.1_amd64.deb ...
# Unpacking firefox (118.0.2+build2-0ubuntu0.20.04.1) ...
# Selecting previously unselected package fonts-urw-base35.
# Preparing to unpack .../fonts-urw-base35_20170801.1-3_all.deb ...
# Unpacking fonts-urw-base35 (20170801.1-3) ...
# Selecting previously unselected package gettext-base.
# Preparing to unpack .../gettext-base_0.19.8.1-10build1_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-10build1) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../gettext_0.19.8.1-10build1_amd64.deb ...
# Unpacking gettext (0.19.8.1-10build1) ...
# Selecting previously unselected package gir1.2-atk-1.0:amd64.
# Preparing to unpack .../gir1.2-atk-1.0_2.35.1-1ubuntu2_amd64.deb ...
# Unpacking gir1.2-atk-1.0:amd64 (2.35.1-1ubuntu2) ...
# Selecting previously unselected package gir1.2-freedesktop:amd64.
# Preparing to unpack .../gir1.2-freedesktop_1.64.1-1~ubuntu20.04.1_amd64.deb ...
# Unpacking gir1.2-freedesktop:amd64 (1.64.1-1~ubuntu20.04.1) ...
# Selecting previously unselected package gir1.2-gdkpixbuf-2.0:amd64.
# Preparing to unpack .../gir1.2-gdkpixbuf-2.0_2.40.0+dfsg-3ubuntu0.4_amd64.deb ...
# Unpacking gir1.2-gdkpixbuf-2.0:amd64 (2.40.0+dfsg-3ubuntu0.4) ...
# Selecting previously unselected package gir1.2-gsf-1:amd64.
# Preparing to unpack .../gir1.2-gsf-1_1.14.46-1_amd64.deb ...
# Unpacking gir1.2-gsf-1:amd64 (1.14.46-1) ...
# Selecting previously unselected package gir1.2-gtk-2.0:amd64.
# Preparing to unpack .../gir1.2-gtk-2.0_2.24.32-4ubuntu4_amd64.deb ...
# Unpacking gir1.2-gtk-2.0:amd64 (2.24.32-4ubuntu4) ...
# Selecting previously unselected package gir1.2-harfbuzz-0.0:amd64.
# Preparing to unpack .../gir1.2-harfbuzz-0.0_2.6.4-1ubuntu4.2_amd64.deb ...
# Unpacking gir1.2-harfbuzz-0.0:amd64 (2.6.4-1ubuntu4.2) ...
# Selecting previously unselected package gir1.2-pango-1.0:amd64.
# Preparing to unpack .../gir1.2-pango-1.0_1.44.7-2ubuntu4_amd64.deb ...
# Unpacking gir1.2-pango-1.0:amd64 (1.44.7-2ubuntu4) ...
# Selecting previously unselected package gir1.2-poppler-0.18:amd64.
# Preparing to unpack .../gir1.2-poppler-0.18_0.86.1-0ubuntu1.3_amd64.deb ...
# Unpacking gir1.2-poppler-0.18:amd64 (0.86.1-0ubuntu1.3) ...
# Selecting previously unselected package gir1.2-rsvg-2.0:amd64.
# Preparing to unpack .../gir1.2-rsvg-2.0_2.48.9-1ubuntu0.20.04.4_amd64.deb ...
# Unpacking gir1.2-rsvg-2.0:amd64 (2.48.9-1ubuntu0.20.04.4) ...
# Selecting previously unselected package gir1.2-vips-8.0.
# Preparing to unpack .../gir1.2-vips-8.0_8.9.1-2_amd64.deb ...
# Unpacking gir1.2-vips-8.0 (8.9.1-2) ...
# Selecting previously unselected package icu-devtools.
# Preparing to unpack .../icu-devtools_66.1-2ubuntu2.1_amd64.deb ...
# Unpacking icu-devtools (66.1-2ubuntu2.1) ...
# Preparing to unpack .../imagemagick-6-common_8%3a6.9.10.23+dfsg-2.1ubuntu11.9_all.deb ...
# Unpacking imagemagick-6-common (8:6.9.10.23+dfsg-2.1ubuntu11.9) over (8:6.9.10.23+dfsg-2.1ubuntu11.7) ...
# Selecting previously unselected package intltool-debian.
# Preparing to unpack .../intltool-debian_0.35.0+20060710.5_all.deb ...
# Unpacking intltool-debian (0.35.0+20060710.5) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../libarchive-cpio-perl_0.10-1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1) ...
# Selecting previously unselected package libarchive-zip-perl.
# Preparing to unpack .../libarchive-zip-perl_1.67-2_all.deb ...
# Unpacking libarchive-zip-perl (1.67-2) ...
# Selecting previously unselected package libatk1.0-dev:amd64.
# Preparing to unpack .../libatk1.0-dev_2.35.1-1ubuntu2_amd64.deb ...
# Unpacking libatk1.0-dev:amd64 (2.35.1-1ubuntu2) ...
# Selecting previously unselected package libblkid-dev:amd64.
# Preparing to unpack .../libblkid-dev_2.34-0.1ubuntu9.4_amd64.deb ...
# Unpacking libblkid-dev:amd64 (2.34-0.1ubuntu9.4) ...
# Selecting previously unselected package libbz2-dev:amd64.
# Preparing to unpack .../libbz2-dev_1.0.8-2_amd64.deb ...
# Unpacking libbz2-dev:amd64 (1.0.8-2) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../libcairo-script-interpreter2_1.16.0-4ubuntu1_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.16.0-4ubuntu1) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../libcairo2-dev_1.16.0-4ubuntu1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.16.0-4ubuntu1) ...
# Selecting previously unselected package libcfitsio-dev:amd64.
# Preparing to unpack .../libcfitsio-dev_3.470-3_amd64.deb ...
# Unpacking libcfitsio-dev:amd64 (3.470-3) ...
# Selecting previously unselected package libcfitsio-doc.
# Preparing to unpack .../libcfitsio-doc_3.470-3_all.deb ...
# Unpacking libcfitsio-doc (3.470-3) ...
# Selecting previously unselected package libcfitsio8:amd64.
# Preparing to unpack .../libcfitsio8_3.470-3_amd64.deb ...
# Unpacking libcfitsio8:amd64 (3.470-3) ...
# Selecting previously unselected package libcroco3:amd64.
# Preparing to unpack .../libcroco3_0.6.13-1_amd64.deb ...
# Unpacking libcroco3:amd64 (0.6.13-1) ...
# Selecting previously unselected package libdatrie-dev:amd64.
# Preparing to unpack .../libdatrie-dev_0.2.12-3_amd64.deb ...
# Unpacking libdatrie-dev:amd64 (0.2.12-3) ...
# Selecting previously unselected package libdbus-glib-1-2:amd64.
# Preparing to unpack .../libdbus-glib-1-2_0.110-5fakssync1_amd64.deb ...
# Unpacking libdbus-glib-1-2:amd64 (0.110-5fakssync1) ...
# Selecting previously unselected package libdbusmenu-glib4:amd64.
# Preparing to unpack .../libdbusmenu-glib4_16.04.1+18.10.20180917-0ubuntu6_amd64.deb ...
# Unpacking libdbusmenu-glib4:amd64 (16.04.1+18.10.20180917-0ubuntu6) ...
# Selecting previously unselected package libdbusmenu-gtk3-4:amd64.
# Preparing to unpack .../libdbusmenu-gtk3-4_16.04.1+18.10.20180917-0ubuntu6_amd64.deb ...
# Unpacking libdbusmenu-gtk3-4:amd64 (16.04.1+18.10.20180917-0ubuntu6) ...
# Selecting previously unselected package libdebhelper-perl.
# Preparing to unpack .../libdebhelper-perl_12.10ubuntu1_all.deb ...
# Unpacking libdebhelper-perl (12.10ubuntu1) ...
# Selecting previously unselected package libdjvulibre-dev:amd64.
# Preparing to unpack .../libdjvulibre-dev_3.5.27.1-14ubuntu0.1_amd64.deb ...
# Unpacking libdjvulibre-dev:amd64 (3.5.27.1-14ubuntu0.1) ...
# Selecting previously unselected package libdjvulibre-text.
# Preparing to unpack .../libdjvulibre-text_3.5.27.1-14ubuntu0.1_all.deb ...
# Unpacking libdjvulibre-text (3.5.27.1-14ubuntu0.1) ...
# Selecting previously unselected package libdjvulibre21:amd64.
# Preparing to unpack .../libdjvulibre21_3.5.27.1-14ubuntu0.1_amd64.deb ...
# Unpacking libdjvulibre21:amd64 (3.5.27.1-14ubuntu0.1) ...
# Selecting previously unselected package libexif-dev:amd64.
# Preparing to unpack .../libexif-dev_0.6.21-6ubuntu0.4_amd64.deb ...
# Unpacking libexif-dev:amd64 (0.6.21-6ubuntu0.4) ...
# Selecting previously unselected package libexif-doc.
# Preparing to unpack .../libexif-doc_0.6.21-6ubuntu0.4_all.deb ...
# Unpacking libexif-doc (0.6.21-6ubuntu0.4) ...
# Selecting previously unselected package libexif-gtk-dev:amd64.
# Preparing to unpack .../libexif-gtk-dev_0.4.0-2_amd64.deb ...
# Unpacking libexif-gtk-dev:amd64 (0.4.0-2) ...
# Selecting previously unselected package libexif-gtk5:amd64.
# Preparing to unpack .../libexif-gtk5_0.4.0-2_amd64.deb ...
# Unpacking libexif-gtk5:amd64 (0.4.0-2) ...
# Selecting previously unselected package libexif12:amd64.
# Preparing to unpack .../libexif12_0.6.21-6ubuntu0.4_amd64.deb ...
# Unpacking libexif12:amd64 (0.6.21-6ubuntu0.4) ...
# Selecting previously unselected package libexpat1-dev:amd64.
# Preparing to unpack .../libexpat1-dev_2.2.9-1ubuntu0.6_amd64.deb ...
# Unpacking libexpat1-dev:amd64 (2.2.9-1ubuntu0.6) ...
# Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../libffi-dev_3.3-4_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.3-4) ...
# Selecting previously unselected package libfftw3-bin.
# Preparing to unpack .../libfftw3-bin_3.3.8-2ubuntu1_amd64.deb ...
# Unpacking libfftw3-bin (3.3.8-2ubuntu1) ...
# Selecting previously unselected package libfftw3-dev:amd64.
# Preparing to unpack .../libfftw3-dev_3.3.8-2ubuntu1_amd64.deb ...
# Unpacking libfftw3-dev:amd64 (3.3.8-2ubuntu1) ...
# Selecting previously unselected package libfftw3-long3:amd64.
# Preparing to unpack .../libfftw3-long3_3.3.8-2ubuntu1_amd64.deb ...
# Unpacking libfftw3-long3:amd64 (3.3.8-2ubuntu1) ...
# Selecting previously unselected package libfftw3-quad3:amd64.
# Preparing to unpack .../libfftw3-quad3_3.3.8-2ubuntu1_amd64.deb ...
# Unpacking libfftw3-quad3:amd64 (3.3.8-2ubuntu1) ...
# Selecting previously unselected package libfftw3-single3:amd64.
# Preparing to unpack .../libfftw3-single3_3.3.8-2ubuntu1_amd64.deb ...
# Unpacking libfftw3-single3:amd64 (3.3.8-2ubuntu1) ...
# Selecting previously unselected package libfile-stripnondeterminism-perl.
# Preparing to unpack .../libfile-stripnondeterminism-perl_1.7.0-1_all.deb ...
# Unpacking libfile-stripnondeterminism-perl (1.7.0-1) ...
# Selecting previously unselected package libfontconfig1-dev:amd64.
# Preparing to unpack .../libfontconfig1-dev_2.13.1-2ubuntu3_amd64.deb ...
# Unpacking libfontconfig1-dev:amd64 (2.13.1-2ubuntu3) ...
# Selecting previously unselected package libfribidi-dev:amd64.
# Preparing to unpack .../libfribidi-dev_1.0.8-2ubuntu0.1_amd64.deb ...
# Unpacking libfribidi-dev:amd64 (1.0.8-2ubuntu0.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../libgail-common_2.24.32-4ubuntu4_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.32-4ubuntu4) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../libgail18_2.24.32-4ubuntu4_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.32-4ubuntu4) ...
# Selecting previously unselected package libgdk-pixbuf2.0-bin.
# Preparing to unpack .../libgdk-pixbuf2.0-bin_2.40.0+dfsg-3ubuntu0.4_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-bin (2.40.0+dfsg-3ubuntu0.4) ...
# Selecting previously unselected package libgdk-pixbuf2.0-dev:amd64.
# Preparing to unpack .../libgdk-pixbuf2.0-dev_2.40.0+dfsg-3ubuntu0.4_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-dev:amd64 (2.40.0+dfsg-3ubuntu0.4) ...
# Selecting previously unselected package libgif-dev.
# Preparing to unpack .../libgif-dev_5.1.9-1_amd64.deb ...
# Unpacking libgif-dev (5.1.9-1) ...
# Selecting previously unselected package libglib2.0-dev-bin.
# Preparing to unpack .../libglib2.0-dev-bin_2.64.6-1~ubuntu20.04.6_amd64.deb ...
# Unpacking libglib2.0-dev-bin (2.64.6-1~ubuntu20.04.6) ...
# Selecting previously unselected package libglib2.0-dev:amd64.
# Preparing to unpack .../libglib2.0-dev_2.64.6-1~ubuntu20.04.6_amd64.deb ...
# Unpacking libglib2.0-dev:amd64 (2.64.6-1~ubuntu20.04.6) ...
# Selecting previously unselected package libgraphite2-dev:amd64.
# Preparing to unpack .../libgraphite2-dev_1.3.13-11build1_amd64.deb ...
# Unpacking libgraphite2-dev:amd64 (1.3.13-11build1) ...
# Selecting previously unselected package libgsf-1-114:amd64.
# Preparing to unpack .../libgsf-1-114_1.14.46-1_amd64.deb ...
# Unpacking libgsf-1-114:amd64 (1.14.46-1) ...
# Selecting previously unselected package libgsf-1-common.
# Preparing to unpack .../libgsf-1-common_1.14.46-1_all.deb ...
# Unpacking libgsf-1-common (1.14.46-1) ...
# Selecting previously unselected package libgsf-1-dev:amd64.
# Preparing to unpack .../libgsf-1-dev_1.14.46-1_amd64.deb ...
# Unpacking libgsf-1-dev:amd64 (1.14.46-1) ...
# Selecting previously unselected package libgsl23:amd64.
# Preparing to unpack .../libgsl23_2.5+dfsg-6build1_amd64.deb ...
# Unpacking libgsl23:amd64 (2.5+dfsg-6build1) ...
# Selecting previously unselected package libgslcblas0:amd64.
# Preparing to unpack .../libgslcblas0_2.5+dfsg-6build1_amd64.deb ...
# Unpacking libgslcblas0:amd64 (2.5+dfsg-6build1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../libgtk2.0-0_2.24.32-4ubuntu4_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.32-4ubuntu4) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../libgtk2.0-bin_2.24.32-4ubuntu4_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.32-4ubuntu4) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../libgtk2.0-common_2.24.32-4ubuntu4_all.deb ...
# Unpacking libgtk2.0-common (2.24.32-4ubuntu4) ...
# Selecting previously unselected package libgtk2.0-dev:amd64.
# Preparing to unpack .../libgtk2.0-dev_2.24.32-4ubuntu4_amd64.deb ...
# Unpacking libgtk2.0-dev:amd64 (2.24.32-4ubuntu4) ...
# Selecting previously unselected package libharfbuzz-dev:amd64.
# Preparing to unpack .../libharfbuzz-dev_2.6.4-1ubuntu4.2_amd64.deb ...
# Unpacking libharfbuzz-dev:amd64 (2.6.4-1ubuntu4.2) ...
# Selecting previously unselected package libharfbuzz-gobject0:amd64.
# Preparing to unpack .../libharfbuzz-gobject0_2.6.4-1ubuntu4.2_amd64.deb ...
# Unpacking libharfbuzz-gobject0:amd64 (2.6.4-1ubuntu4.2) ...
# Selecting previously unselected package libice-dev:amd64.
# Preparing to unpack .../libice-dev_2%3a1.0.10-0ubuntu1_amd64.deb ...
# Unpacking libice-dev:amd64 (2:1.0.10-0ubuntu1) ...
# Selecting previously unselected package libicu-dev:amd64.
# Preparing to unpack .../libicu-dev_66.1-2ubuntu2.1_amd64.deb ...
# Unpacking libicu-dev:amd64 (66.1-2ubuntu2.1) ...
# Selecting previously unselected package libilmbase-dev:amd64.
# Preparing to unpack .../libilmbase-dev_2.3.0-6build1_amd64.deb ...
# Unpacking libilmbase-dev:amd64 (2.3.0-6build1) ...
# Selecting previously unselected package libilmbase24:amd64.
# Preparing to unpack .../libilmbase24_2.3.0-6build1_amd64.deb ...
# Unpacking libilmbase24:amd64 (2.3.0-6build1) ...
# Selecting previously unselected package libimagequant-dev:amd64.
# Preparing to unpack .../libimagequant-dev_2.12.2-1.1_amd64.deb ...
# Unpacking libimagequant-dev:amd64 (2.12.2-1.1) ...
# Selecting previously unselected package libimagequant0:amd64.
# Preparing to unpack .../libimagequant0_2.12.2-1.1_amd64.deb ...
# Unpacking libimagequant0:amd64 (2.12.2-1.1) ...
# Selecting previously unselected package libjbig-dev:amd64.
# Preparing to unpack .../libjbig-dev_2.1-3.1ubuntu0.20.04.1_amd64.deb ...
# Unpacking libjbig-dev:amd64 (2.1-3.1ubuntu0.20.04.1) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../libjs-jquery_3.3.1~dfsg-3_all.deb ...
# Unpacking libjs-jquery (3.3.1~dfsg-3) ...
# Selecting previously unselected package liblcms2-dev:amd64.
# Preparing to unpack .../liblcms2-dev_2.9-4_amd64.deb ...
# Unpacking liblcms2-dev:amd64 (2.9-4) ...
# Selecting previously unselected package liblqr-1-0-dev:amd64.
# Preparing to unpack .../liblqr-1-0-dev_0.4.2-2.1_amd64.deb ...
# Unpacking liblqr-1-0-dev:amd64 (0.4.2-2.1) ...
# Selecting previously unselected package libltdl-dev:amd64.
# Preparing to unpack .../libltdl-dev_2.4.6-14_amd64.deb ...
# Unpacking libltdl-dev:amd64 (2.4.6-14) ...
# Selecting previously unselected package liblzma-dev:amd64.
# Preparing to unpack .../liblzma-dev_5.2.4-1ubuntu1.1_amd64.deb ...
# Unpacking liblzma-dev:amd64 (5.2.4-1ubuntu1.1) ...
# Selecting previously unselected package liblzo2-2:amd64.
# Preparing to unpack .../liblzo2-2_2.10-2_amd64.deb ...
# Unpacking liblzo2-2:amd64 (2.10-2) ...
# Selecting previously unselected package libmagic-mgc.
# Preparing to unpack .../libmagic-mgc_1%3a5.38-4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.38-4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../libmagic1_1%3a5.38-4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.38-4) ...
# Selecting previously unselected package libmagickcore-6-arch-config:amd64.
# Preparing to unpack .../libmagickcore-6-arch-config_8%3a6.9.10.23+dfsg-2.1ubuntu11.9_amd64.deb ...
# Unpacking libmagickcore-6-arch-config:amd64 (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Selecting previously unselected package libmagickcore-6-headers.
# Preparing to unpack .../libmagickcore-6-headers_8%3a6.9.10.23+dfsg-2.1ubuntu11.9_all.deb ...
# Unpacking libmagickcore-6-headers (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Selecting previously unselected package libmagickcore-6.q16-6-extra:amd64.
# Preparing to unpack .../libmagickcore-6.q16-6-extra_8%3a6.9.10.23+dfsg-2.1ubuntu11.9_amd64.deb ...
# Unpacking libmagickcore-6.q16-6-extra:amd64 (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Preparing to unpack .../libmagickcore-6.q16-6_8%3a6.9.10.23+dfsg-2.1ubuntu11.9_amd64.deb ...
# Unpacking libmagickcore-6.q16-6:amd64 (8:6.9.10.23+dfsg-2.1ubuntu11.9) over (8:6.9.10.23+dfsg-2.1ubuntu11.7) ...
# Selecting previously unselected package libmagickcore-6.q16-dev:amd64.
# Preparing to unpack .../libmagickcore-6.q16-dev_8%3a6.9.10.23+dfsg-2.1ubuntu11.9_amd64.deb ...
# Unpacking libmagickcore-6.q16-dev:amd64 (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Selecting previously unselected package libmagickcore-dev.
# Preparing to unpack .../libmagickcore-dev_8%3a6.9.10.23+dfsg-2.1ubuntu11.9_all.deb ...
# Unpacking libmagickcore-dev (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Selecting previously unselected package libmagickwand-6-headers.
# Preparing to unpack .../libmagickwand-6-headers_8%3a6.9.10.23+dfsg-2.1ubuntu11.9_all.deb ...
# Unpacking libmagickwand-6-headers (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Preparing to unpack .../libmagickwand-6.q16-6_8%3a6.9.10.23+dfsg-2.1ubuntu11.9_amd64.deb ...
# Unpacking libmagickwand-6.q16-6:amd64 (8:6.9.10.23+dfsg-2.1ubuntu11.9) over (8:6.9.10.23+dfsg-2.1ubuntu11.7) ...
# Selecting previously unselected package libmagickwand-6.q16-dev:amd64.
# Preparing to unpack .../libmagickwand-6.q16-dev_8%3a6.9.10.23+dfsg-2.1ubuntu11.9_amd64.deb ...
# Unpacking libmagickwand-6.q16-dev:amd64 (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Selecting previously unselected package libmagickwand-dev.
# Preparing to unpack .../libmagickwand-dev_8%3a6.9.10.23+dfsg-2.1ubuntu11.9_all.deb ...
# Unpacking libmagickwand-dev (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../libmail-sendmail-perl_0.80-1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1) ...
# Selecting previously unselected package libmatio-dev:amd64.
# Preparing to unpack .../libmatio-dev_1.5.17-3_amd64.deb ...
# Unpacking libmatio-dev:amd64 (1.5.17-3) ...
# Selecting previously unselected package libmatio9:amd64.
# Preparing to unpack .../libmatio9_1.5.17-3_amd64.deb ...
# Unpacking libmatio9:amd64 (1.5.17-3) ...
# Selecting previously unselected package libmount-dev:amd64.
# Preparing to unpack .../libmount-dev_2.34-0.1ubuntu9.4_amd64.deb ...
# Unpacking libmount-dev:amd64 (2.34-0.1ubuntu9.4) ...
# Selecting previously unselected package libopenexr-dev.
# Preparing to unpack .../libopenexr-dev_2.3.0-6ubuntu0.5_amd64.deb ...
# Unpacking libopenexr-dev (2.3.0-6ubuntu0.5) ...
# Selecting previously unselected package libopenexr24:amd64.
# Preparing to unpack .../libopenexr24_2.3.0-6ubuntu0.5_amd64.deb ...
# Unpacking libopenexr24:amd64 (2.3.0-6ubuntu0.5) ...
# Selecting previously unselected package libopenslide-dev.
# Preparing to unpack .../libopenslide-dev_3.4.1+dfsg-4_amd64.deb ...
# Unpacking libopenslide-dev (3.4.1+dfsg-4) ...
# Selecting previously unselected package liborc-0.4-0:amd64.
# Preparing to unpack .../liborc-0.4-0_1%3a0.4.31-1_amd64.deb ...
# Unpacking liborc-0.4-0:amd64 (1:0.4.31-1) ...
# Selecting previously unselected package liborc-0.4-dev-bin.
# Preparing to unpack .../liborc-0.4-dev-bin_1%3a0.4.31-1_amd64.deb ...
# Unpacking liborc-0.4-dev-bin (1:0.4.31-1) ...
# Selecting previously unselected package liborc-0.4-dev:amd64.
# Preparing to unpack .../liborc-0.4-dev_1%3a0.4.31-1_amd64.deb ...
# Unpacking liborc-0.4-dev:amd64 (1:0.4.31-1) ...
# Selecting previously unselected package libpango1.0-dev:amd64.
# Preparing to unpack .../libpango1.0-dev_1.44.7-2ubuntu4_amd64.deb ...
# Unpacking libpango1.0-dev:amd64 (1.44.7-2ubuntu4) ...
# Selecting previously unselected package libpangoxft-1.0-0:amd64.
# Preparing to unpack .../libpangoxft-1.0-0_1.44.7-2ubuntu4_amd64.deb ...
# Unpacking libpangoxft-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# Selecting previously unselected package libpcre16-3:amd64.
# Preparing to unpack .../libpcre16-3_2%3a8.39-12ubuntu0.1_amd64.deb ...
# Unpacking libpcre16-3:amd64 (2:8.39-12ubuntu0.1) ...
# Selecting previously unselected package libpcre2-16-0:amd64.
# Preparing to unpack .../libpcre2-16-0_10.34-7ubuntu0.1_amd64.deb ...
# Unpacking libpcre2-16-0:amd64 (10.34-7ubuntu0.1) ...
# Selecting previously unselected package libpcre2-32-0:amd64.
# Preparing to unpack .../libpcre2-32-0_10.34-7ubuntu0.1_amd64.deb ...
# Unpacking libpcre2-32-0:amd64 (10.34-7ubuntu0.1) ...
# Selecting previously unselected package libpcre2-dev:amd64.
# Preparing to unpack .../libpcre2-dev_10.34-7ubuntu0.1_amd64.deb ...
# Unpacking libpcre2-dev:amd64 (10.34-7ubuntu0.1) ...
# Selecting previously unselected package libpcre2-posix2:amd64.
# Preparing to unpack .../libpcre2-posix2_10.34-7ubuntu0.1_amd64.deb ...
# Unpacking libpcre2-posix2:amd64 (10.34-7ubuntu0.1) ...
# Selecting previously unselected package libpcre3-dev:amd64.
# Preparing to unpack .../libpcre3-dev_2%3a8.39-12ubuntu0.1_amd64.deb ...
# Unpacking libpcre3-dev:amd64 (2:8.39-12ubuntu0.1) ...
# Selecting previously unselected package libpcre32-3:amd64.
# Preparing to unpack .../libpcre32-3_2%3a8.39-12ubuntu0.1_amd64.deb ...
# Unpacking libpcre32-3:amd64 (2:8.39-12ubuntu0.1) ...
# Selecting previously unselected package libpcrecpp0v5:amd64.
# Preparing to unpack .../libpcrecpp0v5_2%3a8.39-12ubuntu0.1_amd64.deb ...
# Unpacking libpcrecpp0v5:amd64 (2:8.39-12ubuntu0.1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../libpixman-1-dev_0.38.4-0ubuntu2.1_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.38.4-0ubuntu2.1) ...
# Selecting previously unselected package libpoppler-dev:amd64.
# Preparing to unpack .../libpoppler-dev_0.86.1-0ubuntu1.3_amd64.deb ...
# Unpacking libpoppler-dev:amd64 (0.86.1-0ubuntu1.3) ...
# Selecting previously unselected package libpoppler-glib-dev.
# Preparing to unpack .../libpoppler-glib-dev_0.86.1-0ubuntu1.3_amd64.deb ...
# Unpacking libpoppler-glib-dev (0.86.1-0ubuntu1.3) ...
# Selecting previously unselected package libpoppler-glib8:amd64.
# Preparing to unpack .../libpoppler-glib8_0.86.1-0ubuntu1.3_amd64.deb ...
# Unpacking libpoppler-glib8:amd64 (0.86.1-0ubuntu1.3) ...
# Selecting previously unselected package libpoppler97:amd64.
# Preparing to unpack .../libpoppler97_0.86.1-0ubuntu1.3_amd64.deb ...
# Unpacking libpoppler97:amd64 (0.86.1-0ubuntu1.3) ...
# Selecting previously unselected package libpthread-stubs0-dev:amd64.
# Preparing to unpack .../libpthread-stubs0-dev_0.4-1_amd64.deb ...
# Unpacking libpthread-stubs0-dev:amd64 (0.4-1) ...
# Selecting previously unselected package libpython3-all-dev:amd64.
# Preparing to unpack .../libpython3-all-dev_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking libpython3-all-dev:amd64 (3.8.2-0ubuntu2) ...
# Selecting previously unselected package libpython3-dev:amd64.
# Preparing to unpack .../libpython3-dev_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking libpython3-dev:amd64 (3.8.2-0ubuntu2) ...
# Selecting previously unselected package libpython3.8-dev:amd64.
# Preparing to unpack .../libpython3.8-dev_3.8.10-0ubuntu1~20.04.8_amd64.deb ...
# Unpacking libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.8) ...
# Preparing to unpack .../librsvg2-2_2.48.9-1ubuntu0.20.04.4_amd64.deb ...
# Unpacking librsvg2-2:amd64 (2.48.9-1ubuntu0.20.04.4) over (2.48.9-1ubuntu0.20.04.1) ...
# Preparing to unpack .../librsvg2-common_2.48.9-1ubuntu0.20.04.4_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.48.9-1ubuntu0.20.04.4) over (2.48.9-1ubuntu0.20.04.1) ...
# Selecting previously unselected package librsvg2-dev:amd64.
# Preparing to unpack .../librsvg2-dev_2.48.9-1ubuntu0.20.04.4_amd64.deb ...
# Unpacking librsvg2-dev:amd64 (2.48.9-1ubuntu0.20.04.4) ...
# Selecting previously unselected package libselinux1-dev:amd64.
# Preparing to unpack .../libselinux1-dev_3.0-1build2_amd64.deb ...
# Unpacking libselinux1-dev:amd64 (3.0-1build2) ...
# Selecting previously unselected package libsepol1-dev:amd64.
# Preparing to unpack .../libsepol1-dev_3.0-1ubuntu0.1_amd64.deb ...
# Unpacking libsepol1-dev:amd64 (3.0-1ubuntu0.1) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../libsigsegv2_2.12-2_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-2) ...
# Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../libsm-dev_2%3a1.2.3-1_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package libsub-override-perl.
# Preparing to unpack .../libsub-override-perl_0.09-2_all.deb ...
# Unpacking libsub-override-perl (0.09-2) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../libsys-hostname-long-perl_1.5-1_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-1) ...
# Selecting previously unselected package libthai-dev:amd64.
# Preparing to unpack .../libthai-dev_0.1.28-3_amd64.deb ...
# Unpacking libthai-dev:amd64 (0.1.28-3) ...
# Selecting previously unselected package libtiff-dev:amd64.
# Preparing to unpack .../libtiff-dev_4.1.0+git191117-2ubuntu0.20.04.10_amd64.deb ...
# Unpacking libtiff-dev:amd64 (4.1.0+git191117-2ubuntu0.20.04.10) ...
# Preparing to unpack .../libtiff5_4.1.0+git191117-2ubuntu0.20.04.10_amd64.deb ...
# Unpacking libtiff5:amd64 (4.1.0+git191117-2ubuntu0.20.04.10) over (4.1.0+git191117-2ubuntu0.20.04.8) ...
# Selecting previously unselected package libtiffxx5:amd64.
# Preparing to unpack .../libtiffxx5_4.1.0+git191117-2ubuntu0.20.04.10_amd64.deb ...
# Unpacking libtiffxx5:amd64 (4.1.0+git191117-2ubuntu0.20.04.10) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../libtool_2.4.6-14_all.deb ...
# Unpacking libtool (2.4.6-14) ...
# Selecting previously unselected package libvips-dev.
# Preparing to unpack .../libvips-dev_8.9.1-2_amd64.deb ...
# Unpacking libvips-dev (8.9.1-2) ...
# Selecting previously unselected package libvips-doc.
# Preparing to unpack .../libvips-doc_8.9.1-2_all.deb ...
# Unpacking libvips-doc (8.9.1-2) ...
# Selecting previously unselected package libvips-tools.
# Preparing to unpack .../libvips-tools_8.9.1-2_amd64.deb ...
# Unpacking libvips-tools (8.9.1-2) ...
# Selecting previously unselected package libvips42:amd64.
# Preparing to unpack .../libvips42_8.9.1-2_amd64.deb ...
# Unpacking libvips42:amd64 (8.9.1-2) ...
# Selecting previously unselected package libwebp-dev:amd64.
# Preparing to unpack .../libwebp-dev_0.6.1-2ubuntu0.20.04.3_amd64.deb ...
# Unpacking libwebp-dev:amd64 (0.6.1-2ubuntu0.20.04.3) ...
# Preparing to unpack .../libwebp6_0.6.1-2ubuntu0.20.04.3_amd64.deb ...
# Unpacking libwebp6:amd64 (0.6.1-2ubuntu0.20.04.3) over (0.6.1-2ubuntu0.20.04.2) ...
# Selecting previously unselected package libwebpdemux2:amd64.
# Preparing to unpack .../libwebpdemux2_0.6.1-2ubuntu0.20.04.3_amd64.deb ...
# Unpacking libwebpdemux2:amd64 (0.6.1-2ubuntu0.20.04.3) ...
# Preparing to unpack .../libwebpmux3_0.6.1-2ubuntu0.20.04.3_amd64.deb ...
# Unpacking libwebpmux3:amd64 (0.6.1-2ubuntu0.20.04.3) over (0.6.1-2ubuntu0.20.04.2) ...
# Selecting previously unselected package libwmf-dev.
# Preparing to unpack .../libwmf-dev_0.2.8.4-17ubuntu1_amd64.deb ...
# Unpacking libwmf-dev (0.2.8.4-17ubuntu1) ...
# Selecting previously unselected package libwmf0.2-7:amd64.
# Preparing to unpack .../libwmf0.2-7_0.2.8.4-17ubuntu1_amd64.deb ...
# Unpacking libwmf0.2-7:amd64 (0.2.8.4-17ubuntu1) ...
# Preparing to unpack .../libx11-6_2%3a1.6.9-2ubuntu1.6_amd64.deb ...
# Unpacking libx11-6:amd64 (2:1.6.9-2ubuntu1.6) over (2:1.6.9-2ubuntu1.5) ...
# Selecting previously unselected package libx11-dev:amd64.
# Preparing to unpack .../libx11-dev_2%3a1.6.9-2ubuntu1.6_amd64.deb ...
# Unpacking libx11-dev:amd64 (2:1.6.9-2ubuntu1.6) ...
# Selecting previously unselected package libxau-dev:amd64.
# Preparing to unpack .../libxau-dev_1%3a1.0.9-0ubuntu1_amd64.deb ...
# Unpacking libxau-dev:amd64 (1:1.0.9-0ubuntu1) ...
# Selecting previously unselected package libxcb-render0-dev:amd64.
# Preparing to unpack .../libxcb-render0-dev_1.14-2_amd64.deb ...
# Unpacking libxcb-render0-dev:amd64 (1.14-2) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../libxcb-shm0-dev_1.14-2_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.14-2) ...
# Selecting previously unselected package libxcb1-dev:amd64.
# Preparing to unpack .../libxcb1-dev_1.14-2_amd64.deb ...
# Unpacking libxcb1-dev:amd64 (1.14-2) ...
# Selecting previously unselected package libxcomposite-dev:amd64.
# Preparing to unpack .../libxcomposite-dev_1%3a0.4.5-1_amd64.deb ...
# Unpacking libxcomposite-dev:amd64 (1:0.4.5-1) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../libxcursor-dev_1%3a1.2.0-2_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.2.0-2) ...
# Selecting previously unselected package libxdamage-dev:amd64.
# Preparing to unpack .../libxdamage-dev_1%3a1.1.5-2_amd64.deb ...
# Unpacking libxdamage-dev:amd64 (1:1.1.5-2) ...
# Selecting previously unselected package libxdmcp-dev:amd64.
# Preparing to unpack .../libxdmcp-dev_1%3a1.1.3-0ubuntu1_amd64.deb ...
# Unpacking libxdmcp-dev:amd64 (1:1.1.3-0ubuntu1) ...
# Selecting previously unselected package libxext-dev:amd64.
# Preparing to unpack .../libxext-dev_2%3a1.3.4-0ubuntu1_amd64.deb ...
# Unpacking libxext-dev:amd64 (2:1.3.4-0ubuntu1) ...
# Selecting previously unselected package libxfixes-dev:amd64.
# Preparing to unpack .../libxfixes-dev_1%3a5.0.3-2_amd64.deb ...
# Unpacking libxfixes-dev:amd64 (1:5.0.3-2) ...
# Selecting previously unselected package libxft-dev:amd64.
# Preparing to unpack .../libxft-dev_2.3.3-0ubuntu1_amd64.deb ...
# Unpacking libxft-dev:amd64 (2.3.3-0ubuntu1) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../libxi-dev_2%3a1.7.10-0ubuntu1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.7.10-0ubuntu1) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../libxinerama-dev_2%3a1.1.4-2_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.4-2) ...
# Selecting previously unselected package libxml2-dev:amd64.
# Preparing to unpack .../libxml2-dev_2.9.10+dfsg-5ubuntu0.20.04.6_amd64.deb ...
# Unpacking libxml2-dev:amd64 (2.9.10+dfsg-5ubuntu0.20.04.6) ...
# Selecting previously unselected package libxml2-utils.
# Preparing to unpack .../libxml2-utils_2.9.10+dfsg-5ubuntu0.20.04.6_amd64.deb ...
# Unpacking libxml2-utils (2.9.10+dfsg-5ubuntu0.20.04.6) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../libxrandr-dev_2%3a1.5.2-0ubuntu1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.2-0ubuntu1) ...
# Selecting previously unselected package libxrender-dev:amd64.
# Preparing to unpack .../libxrender-dev_1%3a0.9.10-1_amd64.deb ...
# Unpacking libxrender-dev:amd64 (1:0.9.10-1) ...
# Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../libxt-dev_1%3a1.1.5-1_amd64.deb ...
# Unpacking libxt-dev:amd64 (1:1.1.5-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../archives/m4_1.4.18-4_amd64.deb ...
# Unpacking m4 (1.4.18-4) ...
# Selecting previously unselected package nip2.
# Preparing to unpack .../nip2_8.7.0-1_amd64.deb ...
# Unpacking nip2 (8.7.0-1) ...
# Selecting previously unselected package pango1.0-tools.
# Preparing to unpack .../pango1.0-tools_1.44.7-2ubuntu4_amd64.deb ...
# Unpacking pango1.0-tools (1.44.7-2ubuntu4) ...
# Selecting previously unselected package po-debconf.
# Preparing to unpack .../po-debconf_1.0.21_all.deb ...
# Unpacking po-debconf (1.0.21) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../poppler-data_0.4.9-2_all.deb ...
# Unpacking poppler-data (0.4.9-2) ...
# Selecting previously unselected package python3-all-dev.
# Preparing to unpack .../python3-all-dev_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking python3-all-dev (3.8.2-0ubuntu2) ...
# Selecting previously unselected package python3-all.
# Preparing to unpack .../python3-all_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking python3-all (3.8.2-0ubuntu2) ...
# Selecting previously unselected package python3-dev.
# Preparing to unpack .../python3-dev_3.8.2-0ubuntu2_amd64.deb ...
# Unpacking python3-dev (3.8.2-0ubuntu2) ...
# Selecting previously unselected package python3.8-dev.
# Preparing to unpack .../python3.8-dev_3.8.10-0ubuntu1~20.04.8_amd64.deb ...
# Unpacking python3.8-dev (3.8.10-0ubuntu1~20.04.8) ...
# Selecting previously unselected package uuid-dev:amd64.
# Preparing to unpack .../uuid-dev_2.34-0.1ubuntu9.4_amd64.deb ...
# Unpacking uuid-dev:amd64 (2.34-0.1ubuntu9.4) ...
# Selecting previously unselected package x11proto-core-dev.
# Preparing to unpack .../x11proto-core-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-core-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package x11proto-dev.
# Preparing to unpack .../x11proto-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package x11proto-input-dev.
# Preparing to unpack .../x11proto-input-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-input-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package x11proto-randr-dev.
# Preparing to unpack .../x11proto-randr-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-randr-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package x11proto-xext-dev.
# Preparing to unpack .../x11proto-xext-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-xext-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package x11proto-xinerama-dev.
# Preparing to unpack .../x11proto-xinerama-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-xinerama-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package xorg-sgml-doctools.
# Preparing to unpack .../xorg-sgml-doctools_1%3a1.11-1_all.deb ...
# Unpacking xorg-sgml-doctools (1:1.11-1) ...
# Selecting previously unselected package xtrans-dev.
# Preparing to unpack .../xtrans-dev_1.4.0-1_all.deb ...
# Unpacking xtrans-dev (1.4.0-1) ...
# Selecting previously unselected package xul-ext-ubufox.
# Preparing to unpack .../xul-ext-ubufox_3.4-0ubuntu1.17.10.1_all.deb ...
# Unpacking xul-ext-ubufox (3.4-0ubuntu1.17.10.1) ...
# Setting up autopoint (0.19.8.1-10build1) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up bzip2-doc (1.0.8-2) ...
# Setting up dwz (0.13-5) ...
# Setting up fonts-urw-base35 (20170801.1-3) ...
# Setting up gettext-base (0.19.8.1-10build1) ...
# Setting up gir1.2-atk-1.0:amd64 (2.35.1-1ubuntu2) ...
# Setting up gir1.2-freedesktop:amd64 (1.64.1-1~ubuntu20.04.1) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.40.0+dfsg-3ubuntu0.4) ...
# Setting up gir1.2-harfbuzz-0.0:amd64 (2.6.4-1ubuntu4.2) ...
# Setting up icu-devtools (66.1-2ubuntu2.1) ...
# Setting up imagemagick-6-common (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Installing new version of config file /etc/ImageMagick-6/delegates.xml ...
# Setting up javascript-common (11) ...
# Setting up libarchive-cpio-perl (0.10-1) ...
# Setting up libarchive-zip-perl (1.67-2) ...
# Setting up libbz2-dev:amd64 (1.0.8-2) ...
# Setting up libcfitsio-doc (3.470-3) ...
# Setting up libcfitsio8:amd64 (3.470-3) ...
# Setting up libcroco3:amd64 (0.6.13-1) ...
# Setting up libdatrie-dev:amd64 (0.2.12-3) ...
# Setting up libdbus-glib-1-2:amd64 (0.110-5fakssync1) ...
# Setting up libdbusmenu-glib4:amd64 (16.04.1+18.10.20180917-0ubuntu6) ...
# Setting up libdbusmenu-gtk3-4:amd64 (16.04.1+18.10.20180917-0ubuntu6) ...
# Setting up libdebhelper-perl (12.10ubuntu1) ...
# Setting up libdjvulibre-text (3.5.27.1-14ubuntu0.1) ...
# Setting up libdjvulibre21:amd64 (3.5.27.1-14ubuntu0.1) ...
# Setting up libexif12:amd64 (0.6.21-6ubuntu0.4) ...
# Setting up libexpat1-dev:amd64 (2.2.9-1ubuntu0.6) ...
# Setting up libffi-dev:amd64 (3.3-4) ...
# Setting up libfftw3-long3:amd64 (3.3.8-2ubuntu1) ...
# Setting up libfftw3-quad3:amd64 (3.3.8-2ubuntu1) ...
# Setting up libfftw3-single3:amd64 (3.3.8-2ubuntu1) ...
# Setting up libfribidi-dev:amd64 (1.0.8-2ubuntu0.1) ...
# Setting up libgdk-pixbuf2.0-bin (2.40.0+dfsg-3ubuntu0.4) ...
# Setting up libgif-dev (5.1.9-1) ...
# Setting up libglib2.0-dev-bin (2.64.6-1~ubuntu20.04.6) ...
# Setting up libgraphite2-dev:amd64 (1.3.13-11build1) ...
# Setting up libgsf-1-common (1.14.46-1) ...
# Setting up libgslcblas0:amd64 (2.5+dfsg-6build1) ...
# Setting up libgtk2.0-common (2.24.32-4ubuntu4) ...
# Setting up libharfbuzz-gobject0:amd64 (2.6.4-1ubuntu4.2) ...
# Setting up libicu-dev:amd64 (66.1-2ubuntu2.1) ...
# Setting up libilmbase24:amd64 (2.3.0-6build1) ...
# Setting up libimagequant0:amd64 (2.12.2-1.1) ...
# Setting up libjbig-dev:amd64 (2.1-3.1ubuntu0.20.04.1) ...
# Setting up libjs-jquery (3.3.1~dfsg-3) ...
# Setting up liblcms2-dev:amd64 (2.9-4) ...
# Setting up liblqr-1-0-dev:amd64 (0.4.2-2.1) ...
# Setting up liblzma-dev:amd64 (5.2.4-1ubuntu1.1) ...
# Setting up liblzo2-2:amd64 (2.10-2) ...
# Setting up libmagic-mgc (1:5.38-4) ...
# Setting up libmagic1:amd64 (1:5.38-4) ...
# Setting up libmagickcore-6-headers (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Setting up libmagickwand-6-headers (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Setting up libmatio9:amd64 (1.5.17-3) ...
# Setting up libopenexr24:amd64 (2.3.0-6ubuntu0.5) ...
# Setting up libopenslide-dev (3.4.1+dfsg-4) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.31-1) ...
# Setting up liborc-0.4-dev-bin (1:0.4.31-1) ...
# Setting up liborc-0.4-dev:amd64 (1:0.4.31-1) ...
# Setting up libpcre16-3:amd64 (2:8.39-12ubuntu0.1) ...
# Setting up libpcre2-16-0:amd64 (10.34-7ubuntu0.1) ...
# Setting up libpcre2-32-0:amd64 (10.34-7ubuntu0.1) ...
# Setting up libpcre2-posix2:amd64 (10.34-7ubuntu0.1) ...
# Setting up libpcre32-3:amd64 (2:8.39-12ubuntu0.1) ...
# Setting up libpcrecpp0v5:amd64 (2:8.39-12ubuntu0.1) ...
# Setting up libpixman-1-dev:amd64 (0.38.4-0ubuntu2.1) ...
# Setting up libpthread-stubs0-dev:amd64 (0.4-1) ...
# Setting up libpython3.8-dev:amd64 (3.8.10-0ubuntu1~20.04.8) ...
# Setting up librsvg2-2:amd64 (2.48.9-1ubuntu0.20.04.4) ...
# Setting up librsvg2-common:amd64 (2.48.9-1ubuntu0.20.04.4) ...
# Setting up libsepol1-dev:amd64 (3.0-1ubuntu0.1) ...
# Setting up libsigsegv2:amd64 (2.12-2) ...
# Setting up libsub-override-perl (0.09-2) ...
# Setting up libsys-hostname-long-perl (1.5-1) ...
# Setting up libthai-dev:amd64 (0.1.28-3) ...
# Setting up libvips-doc (8.9.1-2) ...
# Setting up libwebp6:amd64 (0.6.1-2ubuntu0.20.04.3) ...
# Setting up libwebpdemux2:amd64 (0.6.1-2ubuntu0.20.04.3) ...
# Setting up libwebpmux3:amd64 (0.6.1-2ubuntu0.20.04.3) ...
# Setting up libx11-6:amd64 (2:1.6.9-2ubuntu1.6) ...
# Setting up libxml2-dev:amd64 (2.9.10+dfsg-5ubuntu0.20.04.6) ...
# Setting up libxml2-utils (2.9.10+dfsg-5ubuntu0.20.04.6) ...
# Setting up m4 (1.4.18-4) ...
# Setting up poppler-data (0.4.9-2) ...
# Setting up python3-all (3.8.2-0ubuntu2) ...
# Setting up python3.8-dev (3.8.10-0ubuntu1~20.04.8) ...
# Setting up uuid-dev:amd64 (2.34-0.1ubuntu9.4) ...
# Setting up xorg-sgml-doctools (1:1.11-1) ...
# Setting up xtrans-dev (1.4.0-1) ...
# Setting up xul-ext-ubufox (3.4-0ubuntu1.17.10.1) ...
# Setting up autoconf (2.69-11.1) ...
# Setting up automake (1:1.16.1-4ubuntu6) ...
# update-alternatives: using /usr/bin/automake-1.16 to provide /usr/bin/automake (automake) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/automake.1.gz because associated file /usr/share/man/man1/automake-1.16.1.gz (of link group automake) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/aclocal.1.gz because associated file /usr/share/man/man1/aclocal-1.16.1.gz (of link group automake) doesn't exist
# Setting up file (1:5.38-4) ...
# Setting up firefox (118.0.2+build2-0ubuntu0.20.04.1) ...
# update-alternatives: using /usr/bin/firefox to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# update-alternatives: using /usr/bin/firefox to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# Please restart all running instances of firefox, or you will experience problems.
# Setting up gettext (0.19.8.1-10build1) ...
# Setting up gir1.2-rsvg-2.0:amd64 (2.48.9-1ubuntu0.20.04.4) ...
# Setting up intltool-debian (0.35.0+20060710.5) ...
# Setting up libblkid-dev:amd64 (2.34-0.1ubuntu9.4) ...
# Setting up libcairo-script-interpreter2:amd64 (1.16.0-4ubuntu1) ...
# Setting up libcfitsio-dev:amd64 (3.470-3) ...
# Setting up libdjvulibre-dev:amd64 (3.5.27.1-14ubuntu0.1) ...
# Setting up libexif-dev:amd64 (0.6.21-6ubuntu0.4) ...
# Setting up libexif-doc (0.6.21-6ubuntu0.4) ...
# Setting up libfftw3-bin (3.3.8-2ubuntu1) ...
# Setting up libfftw3-dev:amd64 (3.3.8-2ubuntu1) ...
# Setting up libfile-stripnondeterminism-perl (1.7.0-1) ...
# Setting up libfontconfig1-dev:amd64 (2.13.1-2ubuntu3) ...
# Setting up libgsf-1-114:amd64 (1.14.46-1) ...
# Setting up libgsl23:amd64 (2.5+dfsg-6build1) ...
# Setting up libgtk2.0-0:amd64 (2.24.32-4ubuntu4) ...
# Setting up libgtk2.0-bin (2.24.32-4ubuntu4) ...
# Setting up libilmbase-dev:amd64 (2.3.0-6build1) ...
# Setting up libimagequant-dev:amd64 (2.12.2-1.1) ...
# Setting up libltdl-dev:amd64 (2.4.6-14) ...
# Setting up libmagickcore-6-arch-config:amd64 (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Setting up libmatio-dev:amd64 (1.5.17-3) ...
# Setting up libmount-dev:amd64 (2.34-0.1ubuntu9.4) ...
# Setting up libopenexr-dev (2.3.0-6ubuntu0.5) ...
# Setting up libpangoxft-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# Setting up libpcre2-dev:amd64 (10.34-7ubuntu0.1) ...
# Setting up libpcre3-dev:amd64 (2:8.39-12ubuntu0.1) ...
# Setting up libpython3-dev:amd64 (3.8.2-0ubuntu2) ...
# Setting up libselinux1-dev:amd64 (3.0-1build2) ...
# Setting up libtiff5:amd64 (4.1.0+git191117-2ubuntu0.20.04.10) ...
# Setting up libtiffxx5:amd64 (4.1.0+git191117-2ubuntu0.20.04.10) ...
# Setting up libtool (2.4.6-14) ...
# Setting up libwebp-dev:amd64 (0.6.1-2ubuntu0.20.04.3) ...
# Setting up libwmf0.2-7:amd64 (0.2.8.4-17ubuntu1) ...
# Setting up pango1.0-tools (1.44.7-2ubuntu4) ...
# Setting up po-debconf (1.0.21) ...
# Setting up python3-dev (3.8.2-0ubuntu2) ...
# Setting up x11proto-dev (2019.2-1ubuntu1) ...
# Setting up x11proto-input-dev (2019.2-1ubuntu1) ...
# Setting up x11proto-randr-dev (2019.2-1ubuntu1) ...
# Setting up x11proto-xext-dev (2019.2-1ubuntu1) ...
# Setting up x11proto-xinerama-dev (2019.2-1ubuntu1) ...
# Setting up dh-strip-nondeterminism (1.7.0-1) ...
# Setting up gir1.2-gsf-1:amd64 (1.14.46-1) ...
# Setting up gir1.2-pango-1.0:amd64 (1.44.7-2ubuntu4) ...
# Setting up libexif-gtk5:amd64 (0.4.0-2) ...
# Setting up libgail18:amd64 (2.24.32-4ubuntu4) ...
# Setting up libglib2.0-dev:amd64 (2.64.6-1~ubuntu20.04.6) ...
# Setting up libice-dev:amd64 (2:1.0.10-0ubuntu1) ...
# Setting up libmagickcore-6.q16-6:amd64 (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Setting up libmagickwand-6.q16-6:amd64 (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Setting up libpoppler97:amd64 (0.86.1-0ubuntu1.3) ...
# Setting up libpython3-all-dev:amd64 (3.8.2-0ubuntu2) ...
# Setting up libsm-dev:amd64 (2:1.2.3-1) ...
# Setting up libtiff-dev:amd64 (4.1.0+git191117-2ubuntu0.20.04.10) ...
# Setting up libxau-dev:amd64 (1:1.0.9-0ubuntu1) ...
# Setting up libxdmcp-dev:amd64 (1:1.1.3-0ubuntu1) ...
# Setting up python3-all-dev (3.8.2-0ubuntu2) ...
# Setting up x11proto-core-dev (2019.2-1ubuntu1) ...
# Setting up gir1.2-gtk-2.0:amd64 (2.24.32-4ubuntu4) ...
# Setting up libgail-common:amd64 (2.24.32-4ubuntu4) ...
# Setting up libmagickcore-6.q16-6-extra:amd64 (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Setting up libpoppler-dev:amd64 (0.86.1-0ubuntu1.3) ...
# Setting up libpoppler-glib8:amd64 (0.86.1-0ubuntu1.3) ...
# Setting up libvips42:amd64 (8.9.1-2) ...
# Setting up libxcb1-dev:amd64 (1.14-2) ...
# Setting up nip2 (8.7.0-1) ...
# Setting up gir1.2-poppler-0.18:amd64 (0.86.1-0ubuntu1.3) ...
# Setting up gir1.2-vips-8.0 (8.9.1-2) ...
# Setting up libvips-tools (8.9.1-2) ...
# Setting up libx11-dev:amd64 (2:1.6.9-2ubuntu1.6) ...
# Setting up libxcb-render0-dev:amd64 (1.14-2) ...
# Setting up libxcb-shm0-dev:amd64 (1.14-2) ...
# Setting up libxext-dev:amd64 (2:1.3.4-0ubuntu1) ...
# Setting up libxfixes-dev:amd64 (1:5.0.3-2) ...
# Setting up libxi-dev:amd64 (2:1.7.10-0ubuntu1) ...
# Setting up libxinerama-dev:amd64 (2:1.1.4-2) ...
# Setting up libxrender-dev:amd64 (1:0.9.10-1) ...
# Setting up libxt-dev:amd64 (1:1.1.5-1) ...
# Setting up libwmf-dev (0.2.8.4-17ubuntu1) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.5-1) ...
# Setting up libxcursor-dev:amd64 (1:1.2.0-2) ...
# Setting up libxdamage-dev:amd64 (1:1.1.5-2) ...
# Setting up libxft-dev:amd64 (2.3.3-0ubuntu1) ...
# Setting up libxrandr-dev:amd64 (2:1.5.2-0ubuntu1) ...
# Setting up dh-autoreconf (19) ...
# Setting up debhelper (12.10ubuntu1) ...
# Processing triggers for libglib2.0-0:amd64 (2.64.6-1~ubuntu20.04.6) ...
# Setting up libgdk-pixbuf2.0-dev:amd64 (2.40.0+dfsg-3ubuntu0.4) ...
# Setting up libgsf-1-dev:amd64 (1.14.46-1) ...
# Setting up libharfbuzz-dev:amd64 (2.6.4-1ubuntu4.2) ...
# Setting up libatk1.0-dev:amd64 (2.35.1-1ubuntu2) ...
# Setting up libcairo2-dev:amd64 (1.16.0-4ubuntu1) ...
# Setting up libpango1.0-dev:amd64 (1.44.7-2ubuntu4) ...
# Setting up libpoppler-glib-dev (0.86.1-0ubuntu1.3) ...
# Setting up librsvg2-dev:amd64 (2.48.9-1ubuntu0.20.04.4) ...
# Setting up libgtk2.0-dev:amd64 (2.24.32-4ubuntu4) ...
# Setting up libmagickcore-6.q16-dev:amd64 (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Setting up libmagickcore-dev (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Setting up libmagickwand-6.q16-dev:amd64 (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Setting up libmagickwand-dev (8:6.9.10.23+dfsg-2.1ubuntu11.9) ...
# Setting up libexif-gtk-dev:amd64 (0.4.0-2) ...
# Setting up libvips-dev (8.9.1-2) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for install-info (6.7.0.dfsg.2-5) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for libgdk-pixbuf2.0-0:amd64 (2.40.0+dfsg-3ubuntu0.4) ...
# Processing triggers for shared-mime-info (1.15-1) ...
# Looking in links: /kaggle/input/pyvips-python-and-deb-package/python_packages/
# Processing /kaggle/input/pyvips-python-and-deb-package/python_packages/pyvips-2.2.2-py2.py3-none-any.whl
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from pyvips) (1.15.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.0->pyvips) (2.21)
# Installing collected packages: pyvips
# Successfully installed pyvips-2.2.2

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import glob
import matplotlib.pyplot as plt
import os
import pyvips
import time
from tqdm import tqdm
import random
from PIL import Image
Image.MAX_IMAGE_PIXELS = None

from scipy.special import softmax


from torch import optim 
from torchvision import transforms, datasets
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import torch.nn as nn

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, balanced_accuracy_score, accuracy_score
    
df_train = pd.read_csv('/kaggle/input/UBC-OCEAN/train.csv')
df_test = pd.read_csv('/kaggle/input/UBC-OCEAN/test.csv')
df_sub = pd.read_csv('/kaggle/input/UBC-OCEAN/sample_submission.csv')

# %%
def extract_tiles_PIL(image_path,
                        patch_size=300, 
                        num_patches=100,
                        scale = 1.,
                        threshold_black_pixel=10*3,
                        threshold_black_background_ratio=0.1, 
                        threshold_variability=0.15):
    
    images = []
    name, _ = os.path.splitext(os.path.basename(image_path))    
    with Image.open(image_path) as image:
        n_patches_h = int(np.floor(image.width/patch_size))
        n_patches_v = int(np.floor(image.height/patch_size))

        grid_h = np.arange(n_patches_h)
        random.shuffle(grid_h)

        grid_v = np.arange(n_patches_v)
        random.shuffle(grid_v)

        counter = 0
        for i in grid_h:
            if counter == num_patches:
                break
            for j in grid_v:
                idx = i*n_patches_h+j
                patch = image.crop((i * patch_size, j * patch_size,
                                   i * patch_size+patch_size, j * patch_size+patch_size,))

                bw = np.sum(patch, axis=2) # black and white image
                num_black_pixels = np.sum(bw<threshold_black_pixel) # threshold 

                if np.mean(bw)>0:
                    variability = (np.std(bw)/np.mean(bw))
                else:
                    variability = 0

                # if Background is more than 10% of image, discard
                condition1 = num_black_pixels < threshold_black_background_ratio*patch_size**2

                # if variability is smaller than 0.1, discard
                condition2 =  variability > threshold_variability

                if (condition1 and condition2):
                    if scale<1:
                        patch = patch.resize((int(scale*patch_size), int(scale*patch_size)))
                    images.append(patch)
                    counter += 1
                    if counter == num_patches:
                        break
        if counter==0:
            image = image.resize(patch_size, patch_size)
            images.append(patch)
            print('no patch found')
            
    return images, int(name)

# %%
def extract_tiles_jirka(image_path, 
                        patch_size=1200,
                        num_patches=100, 
                        scale=0.25, 
                        drop_thr = 0.6,
                        white_thr = 240):
    images = []
    name, _ = os.path.splitext(os.path.basename(image_path))
    im = pyvips.Image.new_from_file(image_path)
    w = h = patch_size
    # https://stackoverflow.com/a/47581978/4521646
    idxs = [(y, y + h, x, x + w) for y in range(0, im.height, h) for x in range(0, im.width, w)]
    # random subsample
    num_patches = num_patches if isinstance(num_patches, int) else int(len(idxs) * num_patches)
    random.shuffle(idxs)
    files = []
    counter = 0
    for y, y_, x, x_ in idxs:
        # https://libvips.github.io/pyvips/vimage.html#pyvips.Image.crop
        tile = im.crop(x, y, min(w, im.width - x), min(h, im.height - y)).numpy()[..., :3]
        if tile.shape[:2] != (h, w):
            tile_ = tile
            tile_size = (h, w) if tile.ndim == 2 else (h, w, tile.shape[2])
            tile = np.zeros(tile_size, dtype=tile.dtype)
            tile[:tile_.shape[0], :tile_.shape[1], ...] = tile_
        black_bg = np.sum(tile, axis=2) == 0
        tile[black_bg, :] = 255
        mask_bg = np.mean(tile, axis=2) > white_thr
        if np.sum(mask_bg) >= (np.prod(mask_bg.shape) * drop_thr):
            #print(f"skip almost empty tile: {k:06}_{int(x_ / w)}-{int(y_ / h)}")
            continue
            
        # print(tile.shape, tile.dtype, tile.min(), tile.max())
        new_size = int(patch_size * scale), int(patch_size * scale)
        images.append(Image.fromarray(tile).resize(new_size, Image.LANCZOS))
        counter+=1
        # need to set counter check as some empty tiles could be skipped earlier
        if counter >= num_patches:
            break
    return images, int(name)

# %%
im_paths = glob.glob('/kaggle/input/UBC-OCEAN/test_images/*.png')
im_sizes = [os.path.getsize(im_path) for im_path in im_paths]
df = pd.DataFrame({'paths':im_paths, 'sizes':im_sizes})
df = df.sort_values('sizes', ascending=True).reset_index()
file_paths = df['paths']
df.head()

sizes = [os.path.getsize(f) for f in file_paths]

start = 0
max_size = 3e9

start_list = [0]
num_files_list = []
while start<len(sizes):
    num_files = np.sum([(np.cumsum(sizes[start:])<max_size)])
    if num_files > 0:
        num_files_list.append(num_files)
    else:
        num_files_list.append(1)
    start += num_files_list[-1]
    start_list.append(start)

# %% [markdown]
# from concurrent.futures import ThreadPoolExecutor
#
# t0 = time.time()
#
# for i, start in enumerate(start_list[:1]):
#     print()
#     num_files = start_list[i+1]-start
#     print(start, num_files)
#     if num_files >1:
#         print(f'Batch {i}/{len(start_list)}: Multi')
#         with ThreadPoolExecutor(max_workers=4) as executor:
#             futures = []
#             for i in range(start, start+num_files):
#                 futures.append(executor.submit(task, i))
#         for future in futures:
#             future.result()
#
#     else:
#         print(f'Batch {i}/{len(start_list)}: Single')
#         task(start)
#     print(f'{start+num_files} files processed ({np.sum(sizes[:start+num_files])/1e9} GB)')
#     print(f'This took {(time.time()-t0)/60} min')

# %% [markdown]
# img_dir = '/kaggle/working/tiles'
# #df = pd.read_csv('/kaggle/input/UBC-OCEAN/test.csv')
#
# fpaths = []
# image_ids = []
# for fname in os.listdir(img_dir):
#     image_id = int(fname.split('_')[0])
#     fpaths.append(os.path.join(img_dir, fname))
#     image_ids.append(image_id)
#
# df_tiles = pd.DataFrame({'image_id':image_ids, 'fpath':fpaths})
# print(df_tiles.head())
#
# #df_tiles['tile_number'] = [int(f.split('.')[0].split('_')[1]) for f in fpaths]
# #df_tiles = df_tiles[df_tiles['tile_number']<tiles_per_image]
# print(len(df_tiles))

# %%
# One Hot encoding
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
df = pd.read_csv('/kaggle/input/UBC-OCEAN/train.csv')
labels = df['label']
l_encoder = LabelEncoder()
l_encoded = l_encoder.fit_transform(labels)

oh_encoder = OneHotEncoder(sparse_output=False)
l_encoded = l_encoded.reshape(len(l_encoded), 1)
oh_encoded = oh_encoder.fit_transform(l_encoded)

def oh_encoding(label):
    l_encoded = l_encoder.transform(label)
    l_encoded = l_encoded.reshape(len(l_encoded), 1)
    oh_encoded = oh_encoder.transform(l_encoded)
    #print(label, l_encoded, oh_encoded)

    return torch.from_numpy(oh_encoded)

def oh_encoding_inv(probs):
    a = np.argmax(probs)
    return l_encoder.inverse_transform([a])[0]

# %%
class TileDataSet(Dataset):
    def __init__(self, idx=0, transform=None, mode='jirka'):
        self.df = df
        self.transform = transform
        self.mode = mode
        if self.mode == 'jirka':
            self.images, self.image_id = extract_tiles_jirka(file_paths[idx],
                                                        patch_size=1200, 
                                                        num_patches=20,
                                                        scale=0.25,
                                                        drop_thr = 0.6,
                                                        white_thr = 240)
        elif self.mode == 'chris':
            Image.MAX_IMAGE_PIXELS = None
            self.images, self.image_id = extract_tiles_PIL(file_paths[idx],
                                                        patch_size=300, 
                                                        num_patches=100,
                                                        scale = 1.,
                                                        threshold_black_pixel=10*3,
                                                        threshold_black_background_ratio=0.1, 
                                                        threshold_variability=0.15)
        
    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):    
        im = self.images[idx]
        im = self.transform(im)
        return im

# %%
from torchvision import transforms
import multiprocessing as mproc
import pytorch_lightning as pl
from torch.utils.data import DataLoader

val_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
    #transforms.Normalize(clr_mean, clr_std),  # custom
])

# %%
class GeM(nn.Module):
    def __init__(self, p=3, eps=1e-6):
        super(GeM, self).__init__()
        self.p = nn.Parameter(torch.ones(1)*p)
        self.eps = eps

    def forward(self, x):
        return self.gem(x, p=self.p, eps=self.eps)
        
    def gem(self, x, p=3, eps=1e-6):
        return F.avg_pool2d(x.clamp(min=eps).pow(p), (x.size(-2), x.size(-1))).pow(1./p)
        
    def __repr__(self):
        return self.__class__.__name__ + \
                '(' + 'p=' + '{:.4f}'.format(self.p.data.tolist()[0]) + \
                ', ' + 'eps=' + str(self.eps) + ')'

# %%
class UBCModel(nn.Module):
    def __init__(self, model_name, num_classes, pretrained=True):
        super(UBCModel, self).__init__()
        self.model = timm.create_model(model_name, pretrained=pretrained)

        in_features = self.model.classifier.in_features
        self.model.classifier = nn.Identity()
        self.model.global_pool = nn.Identity()
        self.pooling = GeM()
        self.linear = nn.Linear(in_features, num_classes)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, images):
        features = self.model(images)
        pooled_features = self.pooling(features).flatten(1)
        output = self.linear(pooled_features)
        return output

    
#model = UBCModel(CONFIG['model_name'], CONFIG['num_classes'], CONFIG['pretrained'])
#model.to(CONFIG['device']);
#torch.save(model, 'model_initial_weights.pt')

# %%
cuda = False
import torch
#model = torch.load('/kaggle/input/training-with-tiles/model_initial_weights.pt')
#ckpt = torch.load('/kaggle/input/training-with-tiles/state_dict_epoch_50.pt',  map_location=torch.device('cpu'))


model = torch.load('/kaggle/input/training-with-tiles-gem-pooling/model_initial_weights.pt',
                   map_location=torch.device('cpu'))
ckpt = torch.load('/kaggle/input/training-with-tiles-gem-pooling/state_dict_epoch_11.pt',  
                  map_location=torch.device('cpu'))


model.load_state_dict(ckpt['model_state_dict'])
model.eval();

# %%
predictions = []
image_ids = []
def infer_single_image(idx):
    tile_dataset = TileDataSet(idx=idx, transform=val_transform, mode='jirka')
    tile_dataloader = DataLoader(tile_dataset,
                                    batch_size=5,
                                    shuffle=False)    
    outputs = []
    for data in tile_dataloader:
        img = data
        if cuda:
            img = img.to(device='cuda')
        output = model(img).detach()

        if cuda:
            output = output.to('cpu')
            torch.cuda.empty_cache()
        #output = oh_encoding_inv(output)
        outputs += output.tolist()

    probs = softmax(np.sum(np.array(outputs), axis=0))
    if np.max(probs)>0.5:
        prediction = oh_encoding_inv(probs)
    else:
        prediction = 'Other'    
    return tile_dataset.image_id, prediction

# %%
from tqdm.auto import tqdm
from joblib import Parallel, delayed

num_files = len(file_paths)

t0 = time.time()
images = Parallel(n_jobs=-1)(
    delayed(infer_single_image)(i)
    for i in tqdm(range(num_files))
)

print(f'Processed {num_files} files, {np.sum(sizes[:num_files])/1e9:.3f} GB')
t1 = time.time()
print(f'This took {(t1-t0)/60} min')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Processed 1 files, 0.650 GB
# This took 0.5137820442517599 min

# %% [markdown]
# df_predictions = pd.DataFrame(images, columns=['image_id', 'label'])
#
# def get_label(image_id):
#     return df_train.set_index('image_id').loc[image_id][0]
#
#
# df_predictions['label_true'] = df_predictions['image_id'].apply(get_label)
#
# pred = df_predictions['label']
# true = df_predictions['label_true']
#
# from sklearn.metrics import accuracy_score, balanced_accuracy_score
# print('accuracy', accuracy_score(true, pred))
# print('balanced accuracy', balanced_accuracy_score(true, pred))

# %%
df_predictions = pd.DataFrame(images, columns=['image_id', 'label'])
df_predictions.to_csv('submission.csv', index = False)

# %%
#df_sub = pd.read_csv('/kaggle/input/UBC-OCEAN/sample_submission.csv')
#df_sub['image_id'] = image_ids
#df_sub['label'] = predicted_labels
#df_sub.to_csv('submission.csv')

#image_ids = df_sub['image_id']
#predicted_labels = ['HGSC' for i in range(len(df_sub))]

#df = pd.DataFrame({'image_id':image_ids, 'label':predicted_labels})
#df.to_csv('submission.csv', index = False)
#df.head()

# %%
! head submission.csv
# Out:
# image_id,label
# 41,HGSC
